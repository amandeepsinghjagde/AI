# %% [markdown]
# # By Amandeep Singh Jagde

# %%
import numpy as np;
import pandas as pd;

# %%
data = pd.read_csv("diabetes.csv")

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#A
from keras.models import Sequential
from keras.layers import Dense

# %%
df_label = data['Outcome']
df_features = data.drop('Outcome', 1)
df_features.replace('?', -99999, inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
dataSetA = data.iloc[:,0:3]

# %%
x_train, x_test, y_train, y_test = train_test_split(dataSetA, df_label, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Dense(8, input_dim=3, activation='relu'))
model.add(Dense(2, activation='softmax'))
model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy'])
model.fit(x_train,y_train, epochs=100, batch_size=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 62/62 [==============================] - 1s 11ms/step - loss: 0.4999 - accuracy: 0.6615 - val_loss: 0.4999 - val_accuracy: 0.6429
# Epoch 2/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4999 - accuracy: 0.6659 - val_loss: 0.4992 - val_accuracy: 0.6429
# Epoch 3/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4707 - accuracy: 0.5584 - val_loss: 0.3646 - val_accuracy: 0.4610
# Epoch 4/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4285 - accuracy: 0.4412 - val_loss: 0.4268 - val_accuracy: 0.3312
# Epoch 5/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4401 - accuracy: 0.4748 - val_loss: 0.4625 - val_accuracy: 0.6429
# Epoch 6/100
# 62/62 [==============================] - 0s 1ms/step - loss: 0.3769 - accuracy: 0.5150 - val_loss: 0.3029 - val_accuracy: 0.3961
# Epoch 7/100
# ...

# %%
#B

# %%
x_train, x_test, y_train, y_test = train_test_split(df_features, df_label, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Dense(500, input_dim=8, activation='sigmoid'))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(2, activation='softmax'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
model.fit(x_train,y_train, epochs=1000, batch_size=70, validation_data=(x_test, y_test))
# Out:
# Epoch 1/1000
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2599 - accuracy: 0.4286 - val_loss: 0.2559 - val_accuracy: 0.6429
# Epoch 2/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2532 - accuracy: 0.5367 - val_loss: 0.2522 - val_accuracy: 0.6429
# Epoch 3/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2514 - accuracy: 0.5894 - val_loss: 0.2504 - val_accuracy: 0.6429
# Epoch 4/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2505 - accuracy: 0.5723 - val_loss: 0.2501 - val_accuracy: 0.6299
# Epoch 5/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2502 - accuracy: 0.5702 - val_loss: 0.2500 - val_accuracy: 0.5779
# Epoch 6/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2501 - accuracy: 0.5863 - val_loss: 0.2500 - val_accuracy: 0.6234
# Epoch 7/1000
# ...
